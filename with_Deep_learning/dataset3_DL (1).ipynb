# %% [markdown]
# <div><font size="4"><center><b>Dataset: ds3</b></center></font></div>

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from wordcloud import WordCloud
import re
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Dense, Embedding, LSTM, Conv1D, MaxPool1D
from sklearn.metrics import classification_report,accuracy_score

# %%
data= pd.read_csv("/content/drive/MyDrive/datasets/ds3.csv")

# %%
data=data.drop(['date'],axis=1)

# %%
data['content']=data['title']+" "+data['text']

# %%
data['content'] = data['content'].astype(str)

# %%
data.head()
# Out:
#                                                title  \
# 0   BREAKING: GOP Chairman Grassley Has Had Enoug...
# 1   Failed GOP Candidates Remembered In Hilarious...
# 2   Mike Pence’s New DC Neighbors Are HILARIOUSLY...
# 3  California AG pledges to defend birth control ...
# 4  AZ RANCHERS Living On US-Mexico Border Destroy...
#
#                                                 text       subject  label  \
# 0  Donald Trump s White House is in chaos, and th...          News      1
# 1  Now that Donald Trump is the presumptive GOP n...          News      1
# 2  Mike Pence is a huge homophobe. He supports ex...          News      1
# 3  SAN FRANCISCO (Reuters) - California Attorney ...  politicsNews      0
# 4  Twisted reasoning is all that comes from Pelos...      politics      1
#
#                                              content
# 0   BREAKING: GOP Chairman Grassley Has Had Enoug...
# 1   Failed GOP Candidates Remembered In Hilarious...
# 2   Mike Pence’s New DC Neighbors Are HILARIOUSLY...
# 3  California AG pledges to defend birth control ...
# 4  AZ RANCHERS Living On US-Mexico Border Destroy...

# %%
#performing stemming
from nltk.stem.porter import PorterStemmer

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
port_stem = PorterStemmer()
stop_words = set(stopwords.words('english'))
pattern = re.compile('[^a-zA-Z]')
def stemming(content, pattern, stop_words, stemmer):
  stem_content = pattern.sub(' ', content)
  stem_content = stem_content.lower().split()
  stem_content = [stemmer.stem(word) for word in stem_content if word not in stop_words]
  stem_content = ' '.join(stem_content)
  return stem_content

# %%
# applying the optimized stemming function to the content
data['content'] = data['content'].apply(stemming, args=(pattern, stop_words, port_stem))

# %%
#wordcloud
content= ' '.join(data['content'].tolist())
import matplotlib.pyplot as plt
wordcloud = WordCloud().generate(content)
fig= plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
#vectorization  using word2vec
X = [d.split() for d in data['content'].tolist()]

# %%
import gensim

DIM = 100
w2v_model = gensim.models.Word2Vec(sentences=X, vector_size=DIM, window=10, min_count=1)

# %%
#check the converted values
w2v_model.wv['us']
# Out:
# array([ 3.2927687 , -3.5438905 ,  1.865465  , -2.4315474 ,  2.267707  ,
#         1.1310667 ,  3.6931572 ,  0.700464  , -0.7595898 , -1.0730617 ,
#        -0.19689243,  2.5656435 ,  1.8483617 , -1.4523327 , -2.6966913 ,
#         1.3751094 , -0.30821842,  1.96992   ,  1.3285669 ,  3.4574177 ,
#        -0.18728168,  1.2442375 , -1.2728554 , -0.33570507, -1.979219  ,
#        -0.94508445,  3.3482568 ,  2.467348  ,  2.3327985 , -2.268407  ,
#         2.1758704 , -1.7428104 ,  0.55207807,  1.046183  , -0.6844096 ,
#         0.4126711 , -1.8886902 ,  2.441073  ,  3.1941888 ,  0.02753316,
#        -0.32612348,  0.6094524 , -0.30616745, -1.5988452 ,  2.6322708 ,
#         3.7813866 , -1.8413777 , -1.041538  , -0.02024847,  1.5416188 ,
#        -0.95617557,  0.0247013 , -0.6409429 , -0.27438322,  3.074866  ,
#        -1.650897  ,  0.8394238 , -1.3807082 , -0.88139975,  1.5792564 ,
#         1.4522766 , -2.270788  ,  0.08132461,  0.51151   , -2.906164  ,
#         0.22154813,  2.736477  , -2.3121605 , -0.8272293 , -0.42446056,
#        -0.6023988 ,  0.94545126, -0.52039415, -0.45086947, -1.9352844 ,
#        -1.7606835 , -0.507941  , -0.62974364, -2.2383256 , -0.8150701 ,
#         0.3232839 , -0.11277183, -2.1252184 ,  1.2020514 , -1.2952635 ,
#        -2.3588135 ,  2.0999136 , -0.63670456, -2.0545056 , -2.5099409 ,
#        -3.1689744 ,  2.5646663 , -1.0120027 , -0.7512302 , -3.3124924 ,
#         2.5756826 , -1.9085906 , -3.8003218 ,  2.1383598 , -0.10917474],
#       dtype=float32)

# %%
w2v_model.wv.most_similar('us')
# Out:
# [('america', 0.5391133427619934),
#  ('naiv', 0.5249712467193604),
#  ('isi', 0.5215186476707458),
#  ('enemi', 0.4999275207519531),
#  ('simpli', 0.49861401319503784),
#  ('somehow', 0.4838859438896179),
#  ('american', 0.4781976640224457),
#  ('go', 0.4774060845375061),
#  ('regim', 0.47696053981781006),
#  ('perhap', 0.47665995359420776)]

# %%
tokenizer= Tokenizer()
tokenizer.fit_on_texts(X)
X= tokenizer.texts_to_sequences(X)

# %%
plt.hist([len(x) for x in X],bins = 10)
plt.show()

# %%
#now for padding the sequences
nos= np.array([len(X) for x in X])
len(nos[nos>1000])
maxlen=1000
X= pad_sequences(X,maxlen=maxlen)

# %%
X.shape
# Out:
# (44898, 1000)

# %%
#assigning the weights
vocab_size= len(tokenizer.word_index)+1
vocab= tokenizer.word_index

# %%
def get_weight_matrix(model):
  
    weight_matrix = np.zeros((vocab_size, DIM))
   
    for word,i in vocab.items():

        weight_matrix[i] = model.wv[word]

    return weight_matrix

# %%
embedding_vectors = get_weight_matrix(w2v_model)

# %%
embedding_vectors.shape
# Out:
# (89888, 100)

# %%
Y= data['label'].values

# %%
##################################.   LSTM model.  #####################################################

# %%
model= Sequential()

# %%
model.add(Embedding(vocab_size, output_dim=DIM, weights=[embedding_vectors],input_length= maxlen, trainable= False))
model.add(LSTM(units=128))
model.add(Dense(1, activation= 'sigmoid'))
model.compile(optimizer='adam', loss= 'binary_crossentropy',metrics= ['acc'])

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size =0.2)

# %%
#training the model
model.fit(X_train,Y_train, validation_split=0.3, epochs=6)
# Out:
# Epoch 1/6
# 786/786 [==============================] - 33s 39ms/step - loss: 0.0694 - acc: 0.9778 - val_loss: 0.0181 - val_acc: 0.9962
# Epoch 2/6
# 786/786 [==============================] - 29s 37ms/step - loss: 0.0206 - acc: 0.9952 - val_loss: 0.0121 - val_acc: 0.9975
# Epoch 3/6
# 786/786 [==============================] - 29s 37ms/step - loss: 0.0074 - acc: 0.9982 - val_loss: 0.0109 - val_acc: 0.9973
# Epoch 4/6
# 786/786 [==============================] - 30s 38ms/step - loss: 0.0049 - acc: 0.9989 - val_loss: 0.0118 - val_acc: 0.9976
# Epoch 5/6
# 786/786 [==============================] - 31s 39ms/step - loss: 0.0033 - acc: 0.9992 - val_loss: 0.0097 - val_acc: 0.9975
# Epoch 6/6
# 786/786 [==============================] - 29s 37ms/step - loss: 0.0348 - acc: 0.9890 - val_loss: 0.0495 - val_acc: 0.9830

# %%
#checking on test dataset
y_pred= (model.predict(X_test)>=0.5).astype(int)
Lstm_acc = accuracy_score(Y_test,y_pred)
print(Lstm_acc)
# Out:
# 281/281 [==============================] - 4s 13ms/step
# 0.9864142538975501

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      4265
#            1       0.99      0.98      0.99      4715
#
#     accuracy                           0.99      8980
#    macro avg       0.99      0.99      0.99      8980
# weighted avg       0.99      0.99      0.99      8980

# %%
#overall model accuracy came out to be 99% for LSTM standard

# %%
#now for randomly testing any news
Z=['WASHINGTON (Reuters) - The special counsel investigation of links between Russia and President Trump’s 2016 election campaign should continue without interference in 2018, despite calls from some Trump administration allies and Republican lawmakers to shut it down, a prominent Republican senator said on Sunday. Lindsey Graham, who serves on the Senate armed forces and judiciary committees, said Department of Justice Special Counsel Robert Mueller needs to carry on with his Russia investigation without political interference. “This investigation will go forward. It will be an investigation conducted without political influence,” Graham said on CBS’s Face the Nation news program. “And we all need to let Mr. Mueller do his job. I think he’s the right guy at the right time.”  The question of how Russia may have interfered in the election, and how Trump’s campaign may have had links with or co-ordinated any such effort, has loomed over the White House since Trump took office in January. It shows no sign of receding as Trump prepares for his second year in power, despite intensified rhetoric from some Trump allies in recent weeks accusing Mueller’s team of bias against the Republican president. Trump himself seemed to undercut his supporters in an interview last week with the New York Times in which he said he expected Mueller was “going to be fair.”    Russia’s role in the election and the question of possible links to the Trump campaign are the focus of multiple inquiries in Washington. Three committees of the Senate and the House of Representatives are investigating, as well as Mueller, whose team in May took over an earlier probe launched by the U.S. Federal Bureau of Investigation (FBI). Several members of the Trump campaign and administration have been convicted or indicted in the investigation.  Trump and his allies deny any collusion with Russia during the campaign, and the Kremlin has denied meddling in the election. Graham said he still wants an examination of the FBI’s use of a dossier on links between Trump and Russia that was compiled by a former British spy, Christopher Steele, which prompted Trump allies and some Republicans to question Mueller’s inquiry.   On Saturday, the New York Times reported that it was not that dossier that triggered an early FBI probe, but a tip from former Trump campaign foreign policy adviser George Papadopoulos to an Australian diplomat that Russia had damaging information about former Trump rival Hillary Clinton.  “I want somebody to look at the way the Department of Justice used this dossier. It bothers me greatly the way they used it, and I want somebody to look at it,” Graham said. But he said the Russia investigation must continue. “As a matter of fact, it would hurt us if we ignored it,” he said.']

# %%
Z= tokenizer.texts_to_sequences(Z)
Z=pad_sequences(Z,maxlen=maxlen)

# %%
print( (model.predict(Z)>=0.5).astype(int))
# Out:
# 1/1 [==============================] - 0s 27ms/step
# [[1]]

# %%
# using different models on same dataset

# %%
##################################.  Bidirectional LSTM model.  #####################################################

# %%
#2. using the bidrectional LSTM

# %%
from keras.layers import Bidirectional

model.add(Embedding(vocab_size, output_dim=DIM, weights=[embedding_vectors], input_length=maxlen, trainable=False))
model.add(Bidirectional(LSTM(units=128)))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss= 'binary_crossentropy', metrics=['acc'])

# %%
#training the model
model.fit(X_train,Y_train, validation_split=0.3, epochs=20)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Gradients do not exist for variables ['lstm_2/lstm_cell_4/kernel:0', 'lstm_2/lstm_cell_4/recurrent_kernel:0', 'lstm_2/lstm_cell_4/bias:0', 'dense_2/kernel:0', 'dense_2/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['lstm_2/lstm_cell_4/kernel:0', 'lstm_2/lstm_cell_4/recurrent_kernel:0', 'lstm_2/lstm_cell_4/bias:0', 'dense_2/kernel:0', 'dense_2/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['lstm_2/lstm_cell_4/kernel:0', 'lstm_2/lstm_cell_4/recurrent_kernel:0', 'lstm_2/lstm_cell_4/bias:0', 'dense_2/kernel:0', 'dense_2/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['lstm_2/lstm_cell_4/kernel:0', 'lstm_2/lstm_cell_4/recurrent_kernel:0', 'lstm_2/lstm_cell_4/bias:0', 'dense_2/kernel:0', 'dense_2/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 786/786 [==============================] - 24s 25ms/step - loss: 0.6924 - acc: 0.5185 - val_loss: 0.6919 - val_acc: 0.5261
# Epoch 2/20
# 786/786 [==============================] - 19s 24ms/step - loss: 0.6924 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261
# Epoch 3/20
# 786/786 [==============================] - 19s 24ms/step - loss: 0.6924 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261
# Epoch 4/20
# 786/786 [==============================] - 19s 24ms/step - loss: 0.6924 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261
# Epoch 5/20
# 786/786 [==============================] - 18s 23ms/step - loss: 0.6924 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261
# Epoch 6/20
# 786/786 [==============================] - 18s 23ms/step - loss: 0.6924 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261
# Epoch 7/20
# 786/786 [==============================] - 18s 23ms/step - loss: 0.6924 - acc: 0.5209 - val_loss: 0.6919 - val_acc: 0.5261
# Epoch 8/20
# 786/786 [==============================] - 18s 23ms/step - loss: 0.6924 - acc: 0.5209 - val_loss: 0.6919 - val_acc: 0.5261
# Epoch 9/20
# 786/786 [==============================] - 19s 24ms/step - loss: 0.6923 - acc: 0.5209 - val_loss: 0.6919 - val_acc: 0.5261
# Epoch 10/20
# 786/786 [==============================] - 19s 24ms/step - loss: 0.6923 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261
# Epoch 11/20
# 786/786 [==============================] - 19s 24ms/step - loss: 0.6924 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261
# Epoch 12/20
# 786/786 [==============================] - 18s 23ms/step - loss: 0.6923 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261
# Epoch 13/20
# 786/786 [==============================] - 19s 24ms/step - loss: 0.6923 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261
# Epoch 14/20
# 786/786 [==============================] - 19s 24ms/step - loss: 0.6923 - acc: 0.5209 - val_loss: 0.6919 - val_acc: 0.5261
# Epoch 15/20
# 786/786 [==============================] - 18s 23ms/step - loss: 0.6923 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261
# Epoch 16/20
# 786/786 [==============================] - 18s 22ms/step - loss: 0.6923 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261
# Epoch 17/20
# 786/786 [==============================] - 18s 23ms/step - loss: 0.6923 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261
# Epoch 18/20
# 786/786 [==============================] - 18s 23ms/step - loss: 0.6923 - acc: 0.5209 - val_loss: 0.6920 - val_acc: 0.5261
# Epoch 19/20
# 786/786 [==============================] - 19s 24ms/step - loss: 0.6923 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261
# Epoch 20/20
# 786/786 [==============================] - 18s 23ms/step - loss: 0.6923 - acc: 0.5209 - val_loss: 0.6918 - val_acc: 0.5261

# %%
#checking on test dataset
y_pred= (model.predict(X_test)>=0.5).astype(int)
Blstm_acc= accuracy_score(Y_test,y_pred)
print(Blstm_acc)
# Out:
# 281/281 [==============================] - 5s 13ms/step
# 0.5250556792873051

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      4265
#            1       0.53      1.00      0.69      4715
#
#     accuracy                           0.53      8980
#    macro avg       0.26      0.50      0.34      8980
# weighted avg       0.28      0.53      0.36      8980
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
############################################.   CNN model  .#####################################################

# %%
#using CNN model
X.shape
# Out:
# (44898, 1000)

# %%
Y.shape
# Out:
# (44898,)

# %%
#using CNN model
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size =0.2)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (35918, 1000)
# (35918,)

# %%
# reshape input data
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
Y_train = np.reshape(Y_train, (Y_train.shape[0], 1))

# Verify new input shapes
print(X_train.shape)
print(Y_train.shape)
# Out:
# (35918, 1000, 1)
# (35918, 1)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

# define model architecture
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# fit the model
model.fit(X_train, Y_train, validation_split=0.3, epochs=10)
# Out:
# Epoch 1/10
# 786/786 [==============================] - 12s 6ms/step - loss: 5.3161 - accuracy: 0.5283 - val_loss: 0.6860 - val_accuracy: 0.5856
# Epoch 2/10
# 786/786 [==============================] - 5s 7ms/step - loss: 0.6824 - accuracy: 0.5698 - val_loss: 0.6713 - val_accuracy: 0.5937
# Epoch 3/10
# 786/786 [==============================] - 5s 6ms/step - loss: 0.6679 - accuracy: 0.6007 - val_loss: 0.6506 - val_accuracy: 0.6343
# Epoch 4/10
# 786/786 [==============================] - 4s 6ms/step - loss: 0.6531 - accuracy: 0.6147 - val_loss: 0.6351 - val_accuracy: 0.6337
# Epoch 5/10
# 786/786 [==============================] - 6s 7ms/step - loss: 0.6450 - accuracy: 0.6201 - val_loss: 0.6322 - val_accuracy: 0.6331
# Epoch 6/10
# 786/786 [==============================] - 5s 6ms/step - loss: 0.6395 - accuracy: 0.6242 - val_loss: 0.6293 - val_accuracy: 0.6332
# Epoch 7/10
# 786/786 [==============================] - 4s 6ms/step - loss: 0.6386 - accuracy: 0.6233 - val_loss: 0.6272 - val_accuracy: 0.6356
# Epoch 8/10
# 786/786 [==============================] - 6s 7ms/step - loss: 0.6369 - accuracy: 0.6248 - val_loss: 0.6250 - val_accuracy: 0.6356
# Epoch 9/10
# 786/786 [==============================] - 5s 6ms/step - loss: 0.6359 - accuracy: 0.6223 - val_loss: 0.6257 - val_accuracy: 0.6359
# Epoch 10/10
# 786/786 [==============================] - 5s 7ms/step - loss: 0.6391 - accuracy: 0.6257 - val_loss: 0.6315 - val_accuracy: 0.6411

# %%
#changing the laarning rate and optimizer to see if the accuracy improves

# %%
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.models import Sequential
from keras.optimizers import Adam

model = Sequential()

# Add a Conv1D layer with 64 filters and kernel size of 5
model.add(Conv1D(filters=64, kernel_size=5, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
# Add a MaxPooling1D layer with pool size of 2
model.add(MaxPooling1D(pool_size=2))
# Add a BatchNormalization layer to normalize the output of the Conv1D layer
model.add(BatchNormalization())

# Add another Conv1D layer with 32 filters and kernel size of 3
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
# Add another MaxPooling1D layer with pool size of 2
model.add(MaxPooling1D(pool_size=2))
# Add another BatchNormalization layer
model.add(BatchNormalization())

# Add a third Conv1D layer with 16 filters and kernel size of 3
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
# Add another MaxPooling1D layer with pool size of 2
model.add(MaxPooling1D(pool_size=2))
# Add another BatchNormalization layer
model.add(BatchNormalization())

# Flatten the output of the Conv1D layers
model.add(Flatten())
# Add a Dropout layer with rate of 0.5 to prevent overfitting
model.add(Dropout(0.5))

# Add a Dense layer with 256 units and 'relu' activation
model.add(Dense(256, activation='relu'))
# Add another Dropout layer
model.add(Dropout(0.5))
# Add a Dense layer with 1 unit and 'sigmoid' activation for binary classification
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the model with Adam optimizer and binary crossentropy loss function
model.compile(optimizer=Adam(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Fit the model on the training data for 50 epochs
history = model.fit(X_train, Y_train, epochs=50, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/50
# 562/562 [==============================] - 7s 10ms/step - loss: 0.6829 - accuracy: 0.6256 - val_loss: 0.6136 - val_accuracy: 0.6741
# Epoch 2/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.6060 - accuracy: 0.6651 - val_loss: 0.7159 - val_accuracy: 0.6008
# Epoch 3/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.5900 - accuracy: 0.6744 - val_loss: 0.7450 - val_accuracy: 0.5383
# Epoch 4/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.5818 - accuracy: 0.6817 - val_loss: 0.5759 - val_accuracy: 0.6849
# Epoch 5/50
# 562/562 [==============================] - 5s 10ms/step - loss: 0.5754 - accuracy: 0.6856 - val_loss: 0.7664 - val_accuracy: 0.5680
# Epoch 6/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.5685 - accuracy: 0.6888 - val_loss: 0.8357 - val_accuracy: 0.5674
# Epoch 7/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.5626 - accuracy: 0.6960 - val_loss: 0.5865 - val_accuracy: 0.6705
# Epoch 8/50
# 562/562 [==============================] - 5s 10ms/step - loss: 0.5608 - accuracy: 0.6971 - val_loss: 0.5652 - val_accuracy: 0.6853
# Epoch 9/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.5522 - accuracy: 0.7056 - val_loss: 0.6390 - val_accuracy: 0.6088
# Epoch 10/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.5467 - accuracy: 0.7094 - val_loss: 0.5841 - val_accuracy: 0.6509
# Epoch 11/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.5418 - accuracy: 0.7127 - val_loss: 0.7147 - val_accuracy: 0.5998
# Epoch 12/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.5362 - accuracy: 0.7200 - val_loss: 0.5566 - val_accuracy: 0.6980
# Epoch 13/50
# 562/562 [==============================] - 6s 10ms/step - loss: 0.5287 - accuracy: 0.7292 - val_loss: 1.7560 - val_accuracy: 0.5659
# Epoch 14/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.5197 - accuracy: 0.7327 - val_loss: 0.5266 - val_accuracy: 0.7305
# Epoch 15/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.5181 - accuracy: 0.7344 - val_loss: 0.5467 - val_accuracy: 0.7072
# Epoch 16/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.5124 - accuracy: 0.7388 - val_loss: 0.7072 - val_accuracy: 0.6186
# Epoch 17/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.5084 - accuracy: 0.7400 - val_loss: 0.6731 - val_accuracy: 0.6224
# Epoch 18/50
# 562/562 [==============================] - 6s 10ms/step - loss: 0.4995 - accuracy: 0.7452 - val_loss: 0.5405 - val_accuracy: 0.7291
# Epoch 19/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4970 - accuracy: 0.7485 - val_loss: 0.5239 - val_accuracy: 0.7481
# Epoch 20/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4945 - accuracy: 0.7531 - val_loss: 0.5399 - val_accuracy: 0.7129
# Epoch 21/50
# 562/562 [==============================] - 5s 10ms/step - loss: 0.4924 - accuracy: 0.7558 - val_loss: 0.5741 - val_accuracy: 0.7017
# Epoch 22/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4910 - accuracy: 0.7552 - val_loss: 0.5040 - val_accuracy: 0.7493
# Epoch 23/50
# 562/562 [==============================] - 5s 10ms/step - loss: 0.4838 - accuracy: 0.7588 - val_loss: 2.0018 - val_accuracy: 0.5463
# Epoch 24/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4804 - accuracy: 0.7591 - val_loss: 0.5563 - val_accuracy: 0.6837
# Epoch 25/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4760 - accuracy: 0.7649 - val_loss: 0.6152 - val_accuracy: 0.6993
# Epoch 26/50
# 562/562 [==============================] - 6s 10ms/step - loss: 0.4729 - accuracy: 0.7683 - val_loss: 0.5012 - val_accuracy: 0.7660
# Epoch 27/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4675 - accuracy: 0.7687 - val_loss: 0.5321 - val_accuracy: 0.7322
# Epoch 28/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4638 - accuracy: 0.7731 - val_loss: 0.5037 - val_accuracy: 0.7486
# Epoch 29/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4669 - accuracy: 0.7720 - val_loss: 0.8350 - val_accuracy: 0.6506
# Epoch 30/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4586 - accuracy: 0.7759 - val_loss: 1.6973 - val_accuracy: 0.5421
# Epoch 31/50
# 562/562 [==============================] - 6s 10ms/step - loss: 0.4578 - accuracy: 0.7764 - val_loss: 0.5641 - val_accuracy: 0.7012
# Epoch 32/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4588 - accuracy: 0.7752 - val_loss: 0.4860 - val_accuracy: 0.7573
# Epoch 33/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4486 - accuracy: 0.7816 - val_loss: 0.7368 - val_accuracy: 0.6901
# Epoch 34/50
# 562/562 [==============================] - 6s 10ms/step - loss: 0.4481 - accuracy: 0.7813 - val_loss: 0.8431 - val_accuracy: 0.6719
# Epoch 35/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4458 - accuracy: 0.7831 - val_loss: 0.8292 - val_accuracy: 0.6500
# Epoch 36/50
# 562/562 [==============================] - 5s 10ms/step - loss: 0.4448 - accuracy: 0.7853 - val_loss: 0.5383 - val_accuracy: 0.7225
# Epoch 37/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4423 - accuracy: 0.7867 - val_loss: 0.6484 - val_accuracy: 0.6835
# Epoch 38/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4389 - accuracy: 0.7899 - val_loss: 0.4854 - val_accuracy: 0.7636
# Epoch 39/50
# 562/562 [==============================] - 5s 10ms/step - loss: 0.4367 - accuracy: 0.7896 - val_loss: 1.6313 - val_accuracy: 0.5839
# Epoch 40/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4335 - accuracy: 0.7902 - val_loss: 0.5016 - val_accuracy: 0.7629
# Epoch 41/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4314 - accuracy: 0.7941 - val_loss: 2.7896 - val_accuracy: 0.5400
# Epoch 42/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4335 - accuracy: 0.7945 - val_loss: 0.7121 - val_accuracy: 0.6576
# Epoch 43/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4293 - accuracy: 0.7945 - val_loss: 0.6806 - val_accuracy: 0.6924
# Epoch 44/50
# 562/562 [==============================] - 5s 10ms/step - loss: 0.4299 - accuracy: 0.7941 - val_loss: 9.6489 - val_accuracy: 0.5549
# Epoch 45/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4298 - accuracy: 0.7941 - val_loss: 0.5064 - val_accuracy: 0.7622
# Epoch 46/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4209 - accuracy: 0.7989 - val_loss: 0.5508 - val_accuracy: 0.7269
# Epoch 47/50
# 562/562 [==============================] - 6s 10ms/step - loss: 0.4191 - accuracy: 0.8016 - val_loss: 0.4670 - val_accuracy: 0.7839
# Epoch 48/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4212 - accuracy: 0.8004 - val_loss: 0.5195 - val_accuracy: 0.7374
# Epoch 49/50
# 562/562 [==============================] - 5s 10ms/step - loss: 0.4173 - accuracy: 0.8003 - val_loss: 1.0545 - val_accuracy: 0.6145
# Epoch 50/50
# 562/562 [==============================] - 5s 9ms/step - loss: 0.4108 - accuracy: 0.8040 - val_loss: 1.4389 - val_accuracy: 0.6004

# %%
Cnn_acc = model.evaluate(X_test, Y_test, verbose=0)
print("Accuracy: %.2f%%" % (Cnn_acc[1]*100))
# Out:
# Accuracy: 60.04%

# %%
#fcn

# %%
from keras.layers import Dense, Dropout, BatchNormalization
from keras.models import Sequential
from keras.optimizers import Adam

model = Sequential()

# Add a Dense layer with 64 units and 'relu' activation, and input shape of (X_train.shape[1],)
model.add(Dense(units=64, activation='relu', input_shape=(X_train.shape[1],)))
# Add a BatchNormalization layer to normalize the output of the Dense layer
model.add(BatchNormalization())

# Add another Dense layer with 32 units and 'relu' activation
model.add(Dense(units=32, activation='relu'))
# Add another BatchNormalization layer
model.add(BatchNormalization())

# Add a third Dense layer with 16 units and 'relu' activation
model.add(Dense(units=16, activation='relu'))
# Add another BatchNormalization layer
model.add(BatchNormalization())

# Add a Dropout layer with rate of 0.5 to prevent overfitting
model.add(Dropout(0.5))

# Add a Dense layer with 256 units and 'relu' activation
model.add(Dense(units=256, activation='relu'))
# Add another Dropout layer
model.add(Dropout(0.5))
# Add a Dense layer with 1 unit and 'sigmoid' activation for binary classification
model.add(Dense(units=1, activation='sigmoid'))

# Compile the model with binary crossentropy loss and Adam optimizer
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %%
# Fit the model on the training data for 50 epochs
history = model.fit(X_train, Y_train, epochs=50, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/50
# 562/562 [==============================] - 5s 6ms/step - loss: 0.6743 - accuracy: 0.5936 - val_loss: 0.6337 - val_accuracy: 0.6440
# Epoch 2/50
# 562/562 [==============================] - 4s 7ms/step - loss: 0.6232 - accuracy: 0.6565 - val_loss: 0.6146 - val_accuracy: 0.6627
# Epoch 3/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.5994 - accuracy: 0.6813 - val_loss: 0.6060 - val_accuracy: 0.6710
# Epoch 4/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.5791 - accuracy: 0.7002 - val_loss: 0.5998 - val_accuracy: 0.6788
# Epoch 5/50
# 562/562 [==============================] - 3s 6ms/step - loss: 0.5593 - accuracy: 0.7143 - val_loss: 0.6061 - val_accuracy: 0.6831
# Epoch 6/50
# 562/562 [==============================] - 4s 7ms/step - loss: 0.5380 - accuracy: 0.7301 - val_loss: 0.5983 - val_accuracy: 0.6864
# Epoch 7/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.5171 - accuracy: 0.7442 - val_loss: 0.5962 - val_accuracy: 0.6901
# Epoch 8/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.4968 - accuracy: 0.7595 - val_loss: 0.6135 - val_accuracy: 0.6817
# Epoch 9/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.4798 - accuracy: 0.7724 - val_loss: 0.6114 - val_accuracy: 0.6843
# Epoch 10/50
# 562/562 [==============================] - 4s 7ms/step - loss: 0.4592 - accuracy: 0.7826 - val_loss: 0.6395 - val_accuracy: 0.6862
# Epoch 11/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.4461 - accuracy: 0.7894 - val_loss: 0.6391 - val_accuracy: 0.6872
# Epoch 12/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.4342 - accuracy: 0.7964 - val_loss: 0.6478 - val_accuracy: 0.6797
# Epoch 13/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.4204 - accuracy: 0.8043 - val_loss: 0.6396 - val_accuracy: 0.6908
# Epoch 14/50
# 562/562 [==============================] - 4s 8ms/step - loss: 0.4035 - accuracy: 0.8135 - val_loss: 0.6637 - val_accuracy: 0.6882
# Epoch 15/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.3990 - accuracy: 0.8157 - val_loss: 0.6537 - val_accuracy: 0.6916
# Epoch 16/50
# 562/562 [==============================] - 3s 6ms/step - loss: 0.3910 - accuracy: 0.8198 - val_loss: 0.6942 - val_accuracy: 0.6860
# Epoch 17/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.3772 - accuracy: 0.8290 - val_loss: 0.6795 - val_accuracy: 0.6870
# Epoch 18/50
# 562/562 [==============================] - 4s 8ms/step - loss: 0.3685 - accuracy: 0.8317 - val_loss: 0.6623 - val_accuracy: 0.6842
# Epoch 19/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.3618 - accuracy: 0.8345 - val_loss: 0.6662 - val_accuracy: 0.6869
# Epoch 20/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.3502 - accuracy: 0.8399 - val_loss: 0.7008 - val_accuracy: 0.6844
# Epoch 21/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.3460 - accuracy: 0.8446 - val_loss: 0.7072 - val_accuracy: 0.6755
# Epoch 22/50
# 562/562 [==============================] - 4s 8ms/step - loss: 0.3414 - accuracy: 0.8447 - val_loss: 0.7112 - val_accuracy: 0.6816
# Epoch 23/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.3344 - accuracy: 0.8500 - val_loss: 0.7421 - val_accuracy: 0.6822
# Epoch 24/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.3325 - accuracy: 0.8498 - val_loss: 0.7082 - val_accuracy: 0.6788
# Epoch 25/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.3216 - accuracy: 0.8549 - val_loss: 0.6800 - val_accuracy: 0.6822
# Epoch 26/50
# 562/562 [==============================] - 4s 7ms/step - loss: 0.3172 - accuracy: 0.8570 - val_loss: 0.7265 - val_accuracy: 0.6826
# Epoch 27/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.3089 - accuracy: 0.8612 - val_loss: 0.7020 - val_accuracy: 0.6850
# Epoch 28/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.3139 - accuracy: 0.8609 - val_loss: 0.7024 - val_accuracy: 0.6844
# Epoch 29/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.3003 - accuracy: 0.8672 - val_loss: 0.7051 - val_accuracy: 0.6821
# Epoch 30/50
# 562/562 [==============================] - 4s 7ms/step - loss: 0.2946 - accuracy: 0.8698 - val_loss: 0.7307 - val_accuracy: 0.6869
# Epoch 31/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.2913 - accuracy: 0.8717 - val_loss: 0.7408 - val_accuracy: 0.6803
# Epoch 32/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.2873 - accuracy: 0.8726 - val_loss: 0.7476 - val_accuracy: 0.6815
# Epoch 33/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.2881 - accuracy: 0.8730 - val_loss: 0.6972 - val_accuracy: 0.6840
# Epoch 34/50
# 562/562 [==============================] - 4s 7ms/step - loss: 0.2822 - accuracy: 0.8760 - val_loss: 0.7196 - val_accuracy: 0.6818
# Epoch 35/50
# 562/562 [==============================] - 3s 6ms/step - loss: 0.2791 - accuracy: 0.8761 - val_loss: 0.7068 - val_accuracy: 0.6879
# Epoch 36/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.2717 - accuracy: 0.8840 - val_loss: 0.7267 - val_accuracy: 0.6837
# Epoch 37/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.2702 - accuracy: 0.8819 - val_loss: 0.7393 - val_accuracy: 0.6862
# Epoch 38/50
# 562/562 [==============================] - 4s 7ms/step - loss: 0.2672 - accuracy: 0.8838 - val_loss: 0.7226 - val_accuracy: 0.6861
# Epoch 39/50
# 562/562 [==============================] - 3s 6ms/step - loss: 0.2662 - accuracy: 0.8825 - val_loss: 0.7275 - val_accuracy: 0.6904
# Epoch 40/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.2647 - accuracy: 0.8857 - val_loss: 0.7597 - val_accuracy: 0.6851
# Epoch 41/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.2599 - accuracy: 0.8876 - val_loss: 0.7635 - val_accuracy: 0.6881
# Epoch 42/50
# 562/562 [==============================] - 4s 7ms/step - loss: 0.2584 - accuracy: 0.8902 - val_loss: 0.7454 - val_accuracy: 0.6816
# Epoch 43/50
# 562/562 [==============================] - 3s 6ms/step - loss: 0.2521 - accuracy: 0.8906 - val_loss: 0.7867 - val_accuracy: 0.6818
# Epoch 44/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.2519 - accuracy: 0.8912 - val_loss: 0.7422 - val_accuracy: 0.6884
# Epoch 45/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.2481 - accuracy: 0.8939 - val_loss: 0.7441 - val_accuracy: 0.6873
# Epoch 46/50
# 562/562 [==============================] - 4s 7ms/step - loss: 0.2460 - accuracy: 0.8937 - val_loss: 0.8112 - val_accuracy: 0.6829
# Epoch 47/50
# 562/562 [==============================] - 3s 6ms/step - loss: 0.2468 - accuracy: 0.8956 - val_loss: 0.7463 - val_accuracy: 0.6931
# Epoch 48/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.2404 - accuracy: 0.8967 - val_loss: 0.8242 - val_accuracy: 0.6863
# Epoch 49/50
# 562/562 [==============================] - 3s 5ms/step - loss: 0.2440 - accuracy: 0.8954 - val_loss: 0.7470 - val_accuracy: 0.6873
# Epoch 50/50
# 562/562 [==============================] - 4s 7ms/step - loss: 0.2418 - accuracy: 0.8985 - val_loss: 0.7746 - val_accuracy: 0.6872

# %%
Fcn_acc = model.evaluate(X_test, Y_test, verbose=0)
print("Accuracy: %.2f%%" % (Fcn_acc[1]*100))
# Out:
# Accuracy: 68.72%

# %%
import matplotlib.pyplot as plt

models = ['LSTM', 'Bidirectional LSTM', 'CNN', 'FCN']
accuracy_scores = [Lstm_acc, Blstm_acc, Cnn_acc[1], Fcn_acc[1]]

# Flatten the accuracy_scores list
accuracy_scores = [score[0] if isinstance(score, list) else score for score in accuracy_scores]

plt.bar(models, accuracy_scores)
plt.title('Accuracy scores for different models')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.show()

# %% [markdown]
# <font size="4">From the above graph it can be noted that LSTM has the largest accuracy=0.9864142538975501</font>

# %%
# Statistical Testing

# %%
import numpy as np
from scipy.stats import friedmanchisquare


model_scores = [np.array([Lstm_acc]), np.array([Blstm_acc]), np.array([Cnn_acc[1]]), np.array([Fcn_acc[1]])]

friedman_value, p_value = friedmanchisquare(*model_scores)

print("Friedman test")
print("--------------")
print("Friedman value:", friedman_value)
print("p-value:", p_value)

if p_value < 0.05:
    print("There is a significant difference in the test accuracy scores of the models.")
else:
    print("There is no significant difference in the test accuracy scores of the models.")
# Out:
# Friedman test
# --------------
# Friedman value: 3.0
# p-value: 0.3916251762710877
# There is no significant difference in the test accuracy scores of the models.

# %%
import numpy as np
from scipy.stats import chisquare

model_scores = [Lstm_acc, Blstm_acc, Cnn_acc[1], Fcn_acc[1]]

expected_score = np.mean(model_scores)

# Calculate the chi-squared test statistic and p-value
chi_stat, p_value = chisquare(model_scores, f_exp=expected_score)

print("Chi-squared test results")
print("-------------------------")
print("Chi-squared statistic:", chi_stat)
print("p-value:", p_value)

if p_value < 0.05:
    print("There is a significant difference in the test accuracy scores of the models.")
else:
    print("There is no significant difference in the test accuracy scores of the models.")
# Out:
# Chi-squared test results
# -------------------------
# Chi-squared statistic: 0.1753608658544584
# p-value: 0.9814653189431641
# There is no significant difference in the test accuracy scores of the models.

# %%
import numpy as np
from scipy.stats import ttest_rel

model_scores = [Lstm_acc, Blstm_acc, Cnn_acc[1], Fcn_acc[1]]

# Perform the paired t-test
t_stat, p_value = ttest_rel(model_scores[:-1], model_scores[1:])

print("Paired t-test results")
print("----------------------")
print("t-statistic:", t_stat)
print("p-value:", p_value)

if p_value < 0.05:
    print("There is a significant difference in the test accuracy scores of the models.")
else:
    print("There is no significant difference in the test accuracy scores of the models.")
# Out:
# Paired t-test results
# ----------------------
# t-statistic: 0.551541453184922
# p-value: 0.6366557734277396
# There is no significant difference in the test accuracy scores of the models.
