# %% [markdown]
# <div><font size="4"><center><b>Dataset: ds6</b></center></font></div>

# %%
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from wordcloud import WordCloud
import re
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Dense, Embedding, LSTM, Conv1D, MaxPool1D
from sklearn.metrics import classification_report,accuracy_score

# %%
data= pd.read_csv("/content/drive/MyDrive/datasets/ds6.csv")

# %%
data=data.drop(['id'],axis=1)
data=data.drop(['date'],axis=1)
data=data.drop(['sources'],axis=1)

# %%
data['content']=data['author']+" "+data['text']

# %%
data.head()
# Out:
#                  author                                              title  \
# 0         Joe Wilkinson  A national organization says Georgia has one o...
# 1            Rick Scott  Says Barack Obama's health care law "will be t...
# 2        J.D. Alexander  Says the Southwest Florida Water Management Di...
# 3             Paul Ryan  "The Congressional Budget Office has this econ...
# 4  Rodney Frelinghuysen  Says the Treasury Department "says 41 percent ...
#
#                              paragraph_based_content  \
# 0  ['A coalition of government watchdog groups la...
# 1  ['As Supreme Court justices embarked on three ...
# 2  ["Here's a new one: The Senate budget committe...
# 3  ['Recently, House Budget chairman Paul Ryan, R...
# 4  ['The millionaires’ tax proposal made its late...
#
#                                                 text  label  \
# 0  A coalition of government watchdog groups last...      1
# 1  As Supreme Court justices embarked on three da...      1
# 2  Here's a new one: The Senate budget committee ...      1
# 3  Recently, House Budget chairman Paul Ryan, R-W...      0
# 4  The millionaires’ tax proposal made its latest...      1
#
#                                              content
# 0  Joe Wilkinson A coalition of government watchd...
# 1  Rick Scott As Supreme Court justices embarked ...
# 2  J.D. Alexander Here's a new one: The Senate bu...
# 3  Paul Ryan Recently, House Budget chairman Paul...
# 4  Rodney Frelinghuysen The millionaires’ tax pro...

# %%
#wordcloud
content= ' '.join(data['content'].tolist())
import matplotlib.pyplot as plt
wordcloud = WordCloud().generate(content)
fig= plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
#performing stemming
from nltk.stem.porter import PorterStemmer

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
port_stem = PorterStemmer()
stop_words = set(stopwords.words('english'))
pattern = re.compile('[^a-zA-Z]')

def stemming(content, pattern, stop_words, stemmer):
  stem_content = pattern.sub(' ', content)
  stem_content = stem_content.lower().split()
  stem_content = [stemmer.stem(word) for word in stem_content if word not in stop_words]
  stem_content = ' '.join(stem_content)
  return stem_content

# %%
# applying the optimized stemming function to the content
data['content'] = data['content'].apply(stemming, args=(pattern, stop_words, port_stem))

# %%
#vectorization  using word2vec
X = [d.split() for d in data['content'].tolist()]

# %%
import gensim

DIM = 100
w2v_model = gensim.models.Word2Vec(sentences=X, vector_size=DIM, window=10, min_count=1)

# %%
w2v_model.wv.most_similar('us')
# Out:
# [('punditfact', 0.7354008555412292),
#  ('politifact', 0.6250710487365723),
#  ('baugh', 0.6163769960403442),
#  ('overleverag', 0.573084831237793),
#  ('sciencedaili', 0.5639798045158386),
#  ('huffpostl', 0.5571423172950745),
#  ('anthi', 0.5562309622764587),
#  ('kernen', 0.5391885638237),
#  ('tpmdc', 0.5372586250305176),
#  ('priyono', 0.5350378751754761)]

# %%
tokenizer= Tokenizer()
tokenizer.fit_on_texts(X)
X= tokenizer.texts_to_sequences(X)

# %%
plt.hist([len(x) for x in X],bins = 10)
plt.show()

# %%
#now for padding the sequences
nos= np.array([len(X) for x in X])
len(nos[nos>1000])
maxlen=1000
X= pad_sequences(X,maxlen=maxlen)

# %%
X.shape
# Out:
# (15212, 1000)

# %%
#assigning the weights
vocab_size= len(tokenizer.word_index)+1
vocab= tokenizer.word_index

# %%
def get_weight_matrix(model):
  
    weight_matrix = np.zeros((vocab_size, DIM))
   
    for word,i in vocab.items():

        weight_matrix[i] = model.wv[word]

    return weight_matrix

# %%
embedding_vectors = get_weight_matrix(w2v_model)

# %%
embedding_vectors.shape
# Out:
# (46529, 100)

# %%
Y= data['label'].values

# %%
##################################.   LSTM model.  #####################################################

# %%
model= Sequential()

# %%
model.add(Embedding(vocab_size, output_dim=DIM, weights=[embedding_vectors],input_length= maxlen, trainable= False))
model.add(LSTM(units=128))
model.add(Dense(1, activation= 'sigmoid'))
model.compile(optimizer='adam', loss= 'binary_crossentropy',metrics= ['acc'])

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size =0.2)

# %%
#training the model
model.fit(X_train,Y_train, validation_split=0.3, epochs=6)
# Out:
# Epoch 1/6
# 267/267 [==============================] - 23s 69ms/step - loss: 0.6234 - acc: 0.6230 - val_loss: 0.6069 - val_acc: 0.6382
# Epoch 2/6
# 267/267 [==============================] - 13s 48ms/step - loss: 0.5533 - acc: 0.7074 - val_loss: 0.5966 - val_acc: 0.6519
# Epoch 3/6
# 267/267 [==============================] - 9s 35ms/step - loss: 0.4895 - acc: 0.7576 - val_loss: 0.6273 - val_acc: 0.6554
# Epoch 4/6
# 267/267 [==============================] - 11s 41ms/step - loss: 0.4039 - acc: 0.8178 - val_loss: 0.6480 - val_acc: 0.6546
# Epoch 5/6
# 267/267 [==============================] - 10s 38ms/step - loss: 0.2906 - acc: 0.8889 - val_loss: 0.7272 - val_acc: 0.6371
# Epoch 6/6
# 267/267 [==============================] - 10s 36ms/step - loss: 0.1751 - acc: 0.9454 - val_loss: 0.8336 - val_acc: 0.6360

# %%
#checking on test dataset
y_pred= (model.predict(X_test)>=0.5).astype(int)
Lstm_acc = accuracy_score(Y_test,y_pred)
print(Lstm_acc)
# Out:
# 96/96 [==============================] - 2s 15ms/step
# 0.6148537627341439

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.68      0.64      1540
#            1       0.63      0.55      0.58      1503
#
#     accuracy                           0.61      3043
#    macro avg       0.62      0.61      0.61      3043
# weighted avg       0.62      0.61      0.61      3043

# %%
#overall model accuracy came out to be 99% for LSTM standard

# %%
#now for randomly testing any news
Z=['WASHINGTON (Reuters) - The special counsel investigation of links between Russia and President Trump’s 2016 election campaign should continue without interference in 2018, despite calls from some Trump administration allies and Republican lawmakers to shut it down, a prominent Republican senator said on Sunday. Lindsey Graham, who serves on the Senate armed forces and judiciary committees, said Department of Justice Special Counsel Robert Mueller needs to carry on with his Russia investigation without political interference. “This investigation will go forward. It will be an investigation conducted without political influence,” Graham said on CBS’s Face the Nation news program. “And we all need to let Mr. Mueller do his job. I think he’s the right guy at the right time.”  The question of how Russia may have interfered in the election, and how Trump’s campaign may have had links with or co-ordinated any such effort, has loomed over the White House since Trump took office in January. It shows no sign of receding as Trump prepares for his second year in power, despite intensified rhetoric from some Trump allies in recent weeks accusing Mueller’s team of bias against the Republican president. Trump himself seemed to undercut his supporters in an interview last week with the New York Times in which he said he expected Mueller was “going to be fair.”    Russia’s role in the election and the question of possible links to the Trump campaign are the focus of multiple inquiries in Washington. Three committees of the Senate and the House of Representatives are investigating, as well as Mueller, whose team in May took over an earlier probe launched by the U.S. Federal Bureau of Investigation (FBI). Several members of the Trump campaign and administration have been convicted or indicted in the investigation.  Trump and his allies deny any collusion with Russia during the campaign, and the Kremlin has denied meddling in the election. Graham said he still wants an examination of the FBI’s use of a dossier on links between Trump and Russia that was compiled by a former British spy, Christopher Steele, which prompted Trump allies and some Republicans to question Mueller’s inquiry.   On Saturday, the New York Times reported that it was not that dossier that triggered an early FBI probe, but a tip from former Trump campaign foreign policy adviser George Papadopoulos to an Australian diplomat that Russia had damaging information about former Trump rival Hillary Clinton.  “I want somebody to look at the way the Department of Justice used this dossier. It bothers me greatly the way they used it, and I want somebody to look at it,” Graham said. But he said the Russia investigation must continue. “As a matter of fact, it would hurt us if we ignored it,” he said.']

# %%
Z= tokenizer.texts_to_sequences(Z)
Z=pad_sequences(Z,maxlen=maxlen)

# %%
print( (model.predict(Z)>=0.5).astype(int))
# Out:
# 1/1 [==============================] - 0s 38ms/step
# [[1]]

# %%
# using different models on same dataset

# %%
##################################.  Bidirectional LSTM model.  #####################################################

# %%
#2. using the bidrectional LSTM

# %%
from keras.layers import Bidirectional

model.add(Embedding(vocab_size, output_dim=DIM, weights=[embedding_vectors], input_length=maxlen, trainable=False))
model.add(Bidirectional(LSTM(units=128)))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss= 'binary_crossentropy', metrics=['acc'])

# %%
#training the model
model.fit(X_train,Y_train, validation_split=0.3, epochs=20)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Gradients do not exist for variables ['lstm_6/lstm_cell_12/kernel:0', 'lstm_6/lstm_cell_12/recurrent_kernel:0', 'lstm_6/lstm_cell_12/bias:0', 'dense_33/kernel:0', 'dense_33/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['lstm_6/lstm_cell_12/kernel:0', 'lstm_6/lstm_cell_12/recurrent_kernel:0', 'lstm_6/lstm_cell_12/bias:0', 'dense_33/kernel:0', 'dense_33/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['lstm_6/lstm_cell_12/kernel:0', 'lstm_6/lstm_cell_12/recurrent_kernel:0', 'lstm_6/lstm_cell_12/bias:0', 'dense_33/kernel:0', 'dense_33/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['lstm_6/lstm_cell_12/kernel:0', 'lstm_6/lstm_cell_12/recurrent_kernel:0', 'lstm_6/lstm_cell_12/bias:0', 'dense_33/kernel:0', 'dense_33/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 267/267 [==============================] - 12s 30ms/step - loss: 0.6933 - acc: 0.4952 - val_loss: 0.6932 - val_acc: 0.4944
# Epoch 2/20
# 267/267 [==============================] - 6s 24ms/step - loss: 0.6932 - acc: 0.4872 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 3/20
# 267/267 [==============================] - 6s 22ms/step - loss: 0.6932 - acc: 0.4987 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 4/20
# 267/267 [==============================] - 7s 25ms/step - loss: 0.6932 - acc: 0.5015 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 5/20
# 267/267 [==============================] - 7s 26ms/step - loss: 0.6932 - acc: 0.4964 - val_loss: 0.6932 - val_acc: 0.4944
# Epoch 6/20
# 267/267 [==============================] - 8s 29ms/step - loss: 0.6932 - acc: 0.5027 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 7/20
# 267/267 [==============================] - 7s 26ms/step - loss: 0.6932 - acc: 0.5015 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 8/20
# 267/267 [==============================] - 7s 27ms/step - loss: 0.6932 - acc: 0.4994 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 9/20
# 267/267 [==============================] - 7s 27ms/step - loss: 0.6932 - acc: 0.4971 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 10/20
# 267/267 [==============================] - 6s 23ms/step - loss: 0.6932 - acc: 0.4959 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 11/20
# 267/267 [==============================] - 7s 28ms/step - loss: 0.6932 - acc: 0.4973 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 12/20
# 267/267 [==============================] - 7s 26ms/step - loss: 0.6932 - acc: 0.5015 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 13/20
# 267/267 [==============================] - 6s 24ms/step - loss: 0.6932 - acc: 0.4966 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 14/20
# 267/267 [==============================] - 6s 22ms/step - loss: 0.6932 - acc: 0.5011 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 15/20
# 267/267 [==============================] - 8s 28ms/step - loss: 0.6932 - acc: 0.4980 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 16/20
# 267/267 [==============================] - 6s 22ms/step - loss: 0.6932 - acc: 0.5015 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 17/20
# 267/267 [==============================] - 7s 27ms/step - loss: 0.6932 - acc: 0.5015 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 18/20
# 267/267 [==============================] - 6s 23ms/step - loss: 0.6932 - acc: 0.4992 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 19/20
# 267/267 [==============================] - 6s 22ms/step - loss: 0.6932 - acc: 0.4992 - val_loss: 0.6931 - val_acc: 0.5056
# Epoch 20/20
# 267/267 [==============================] - 8s 29ms/step - loss: 0.6932 - acc: 0.5015 - val_loss: 0.6931 - val_acc: 0.5056

# %%
#checking on test dataset
y_pred= (model.predict(X_test)>=0.5).astype(int)
Blstm_acc= accuracy_score(Y_test,y_pred)
print(Blstm_acc)
# Out:
# 96/96 [==============================] - 2s 16ms/step
# 0.4939204732172198

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1540
#            1       0.49      1.00      0.66      1503
#
#     accuracy                           0.49      3043
#    macro avg       0.25      0.50      0.33      3043
# weighted avg       0.24      0.49      0.33      3043
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   "{0} ill-defined and being set to 0.0 {{0}} "
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   "{0} ill-defined and being set to 0.0 {{0}} "
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   "{0} ill-defined and being set to 0.0 {{0}} "

# %%
############################################.   CNN model  .#####################################################

# %%
#using CNN model
X.shape
# Out:
# (15212, 1000)

# %%
Y.shape
# Out:
# (15212,)

# %%
#using CNN model
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size =0.2)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (12169, 1000)
# (12169,)

# %%
# reshape input data
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
Y_train = np.reshape(Y_train, (Y_train.shape[0], 1))

# Verify new input shapes
print(X_train.shape)
print(Y_train.shape)
# Out:
# (12169, 1000, 1)
# (12169, 1)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

# define model architecture
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# fit the model
model.fit(X_train, Y_train, validation_split=0.3, epochs=10)
# Out:
# Epoch 1/10
# 267/267 [==============================] - 5s 7ms/step - loss: 9.8694 - accuracy: 0.4959 - val_loss: 0.6972 - val_accuracy: 0.5064
# Epoch 2/10
# 267/267 [==============================] - 2s 6ms/step - loss: 0.6974 - accuracy: 0.5008 - val_loss: 0.6993 - val_accuracy: 0.5018
# Epoch 3/10
# 267/267 [==============================] - 2s 6ms/step - loss: 0.6931 - accuracy: 0.4981 - val_loss: 0.6956 - val_accuracy: 0.5004
# Epoch 4/10
# 267/267 [==============================] - 2s 6ms/step - loss: 0.6915 - accuracy: 0.4993 - val_loss: 0.6940 - val_accuracy: 0.5045
# Epoch 5/10
# 267/267 [==============================] - 2s 6ms/step - loss: 0.6919 - accuracy: 0.4955 - val_loss: 0.6946 - val_accuracy: 0.4999
# Epoch 6/10
# 267/267 [==============================] - 2s 6ms/step - loss: 0.6912 - accuracy: 0.5109 - val_loss: 0.7108 - val_accuracy: 0.4985
# Epoch 7/10
# 267/267 [==============================] - 2s 8ms/step - loss: 0.6946 - accuracy: 0.5004 - val_loss: 0.6945 - val_accuracy: 0.4974
# Epoch 8/10
# 267/267 [==============================] - 2s 8ms/step - loss: 0.6925 - accuracy: 0.4986 - val_loss: 0.6937 - val_accuracy: 0.4963
# Epoch 9/10
# 267/267 [==============================] - 2s 7ms/step - loss: 0.6937 - accuracy: 0.5029 - val_loss: 0.6932 - val_accuracy: 0.5012
# Epoch 10/10
# 267/267 [==============================] - 2s 6ms/step - loss: 0.6924 - accuracy: 0.4978 - val_loss: 0.6937 - val_accuracy: 0.4990

# %%
#changing the laarning rate and optimizer to see if the accuracy improves

# %%
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from keras.models import Sequential
from keras.optimizers import Adam

model = Sequential()

# Add a Conv1D layer with 64 filters and kernel size of 5
model.add(Conv1D(filters=64, kernel_size=5, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
# Add a MaxPooling1D layer with pool size of 2
model.add(MaxPooling1D(pool_size=2))
# Add a BatchNormalization layer to normalize the output of the Conv1D layer
model.add(BatchNormalization())

# Add another Conv1D layer with 32 filters and kernel size of 3
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
# Add another MaxPooling1D layer with pool size of 2
model.add(MaxPooling1D(pool_size=2))
# Add another BatchNormalization layer
model.add(BatchNormalization())

# Add a third Conv1D layer with 16 filters and kernel size of 3
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
# Add another MaxPooling1D layer with pool size of 2
model.add(MaxPooling1D(pool_size=2))
# Add another BatchNormalization layer
model.add(BatchNormalization())

# Flatten the output of the Conv1D layers
model.add(Flatten())
# Add a Dropout layer with rate of 0.5 to prevent overfitting
model.add(Dropout(0.5))

# Add a Dense layer with 256 units and 'relu' activation
model.add(Dense(256, activation='relu'))
# Add another Dropout layer
model.add(Dropout(0.5))
# Add a Dense layer with 1 unit and 'sigmoid' activation for binary classification
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the model with Adam optimizer and binary crossentropy loss function
model.compile(optimizer=Adam(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Fit the model on the training data for 50 epochs
history = model.fit(X_train, Y_train, epochs=50, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/50
# 191/191 [==============================] - 4s 11ms/step - loss: 0.8067 - accuracy: 0.5163 - val_loss: 0.7043 - val_accuracy: 0.5409
# Epoch 2/50
# 191/191 [==============================] - 2s 8ms/step - loss: 0.7005 - accuracy: 0.5417 - val_loss: 0.6930 - val_accuracy: 0.5409
# Epoch 3/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.6845 - accuracy: 0.5508 - val_loss: 0.6808 - val_accuracy: 0.5600
# Epoch 4/50
# 191/191 [==============================] - 2s 10ms/step - loss: 0.6845 - accuracy: 0.5471 - val_loss: 0.6846 - val_accuracy: 0.5524
# Epoch 5/50
# 191/191 [==============================] - 2s 11ms/step - loss: 0.6773 - accuracy: 0.5592 - val_loss: 0.6860 - val_accuracy: 0.5662
# Epoch 6/50
# 191/191 [==============================] - 2s 11ms/step - loss: 0.6736 - accuracy: 0.5722 - val_loss: 0.6862 - val_accuracy: 0.5662
# Epoch 7/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.6689 - accuracy: 0.5794 - val_loss: 0.6906 - val_accuracy: 0.5711
# Epoch 8/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.6627 - accuracy: 0.5792 - val_loss: 0.6909 - val_accuracy: 0.5587
# Epoch 9/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.6576 - accuracy: 0.5880 - val_loss: 0.6864 - val_accuracy: 0.5639
# Epoch 10/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.6551 - accuracy: 0.5925 - val_loss: 0.6974 - val_accuracy: 0.5426
# Epoch 11/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.6499 - accuracy: 0.6025 - val_loss: 0.6894 - val_accuracy: 0.5610
# Epoch 12/50
# 191/191 [==============================] - 2s 10ms/step - loss: 0.6445 - accuracy: 0.6090 - val_loss: 0.6935 - val_accuracy: 0.5554
# Epoch 13/50
# 191/191 [==============================] - 2s 11ms/step - loss: 0.6375 - accuracy: 0.6196 - val_loss: 0.6953 - val_accuracy: 0.5583
# Epoch 14/50
# 191/191 [==============================] - 2s 12ms/step - loss: 0.6294 - accuracy: 0.6181 - val_loss: 0.6974 - val_accuracy: 0.5593
# Epoch 15/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.6285 - accuracy: 0.6227 - val_loss: 0.7014 - val_accuracy: 0.5531
# Epoch 16/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.6212 - accuracy: 0.6364 - val_loss: 0.7047 - val_accuracy: 0.5478
# Epoch 17/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.6130 - accuracy: 0.6404 - val_loss: 0.7051 - val_accuracy: 0.5521
# Epoch 18/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.6070 - accuracy: 0.6535 - val_loss: 0.7272 - val_accuracy: 0.5350
# Epoch 19/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.6032 - accuracy: 0.6534 - val_loss: 0.7175 - val_accuracy: 0.5518
# Epoch 20/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.5900 - accuracy: 0.6649 - val_loss: 0.7260 - val_accuracy: 0.5399
# Epoch 21/50
# 191/191 [==============================] - 2s 11ms/step - loss: 0.5818 - accuracy: 0.6744 - val_loss: 0.7234 - val_accuracy: 0.5498
# Epoch 22/50
# 191/191 [==============================] - 2s 12ms/step - loss: 0.5802 - accuracy: 0.6761 - val_loss: 0.7292 - val_accuracy: 0.5465
# Epoch 23/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.5704 - accuracy: 0.6817 - val_loss: 0.7234 - val_accuracy: 0.5478
# Epoch 24/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.5643 - accuracy: 0.6932 - val_loss: 0.7137 - val_accuracy: 0.5554
# Epoch 25/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.5613 - accuracy: 0.6923 - val_loss: 0.7121 - val_accuracy: 0.5478
# Epoch 26/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.5502 - accuracy: 0.6985 - val_loss: 0.7213 - val_accuracy: 0.5393
# Epoch 27/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.5370 - accuracy: 0.7115 - val_loss: 0.7362 - val_accuracy: 0.5458
# Epoch 28/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.5326 - accuracy: 0.7138 - val_loss: 0.7428 - val_accuracy: 0.5380
# Epoch 29/50
# 191/191 [==============================] - 2s 11ms/step - loss: 0.5236 - accuracy: 0.7258 - val_loss: 0.7414 - val_accuracy: 0.5373
# Epoch 30/50
# 191/191 [==============================] - 2s 11ms/step - loss: 0.5178 - accuracy: 0.7288 - val_loss: 0.7569 - val_accuracy: 0.5222
# Epoch 31/50
# 191/191 [==============================] - 2s 10ms/step - loss: 0.5185 - accuracy: 0.7295 - val_loss: 0.7483 - val_accuracy: 0.5343
# Epoch 32/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.5047 - accuracy: 0.7317 - val_loss: 0.7603 - val_accuracy: 0.5422
# Epoch 33/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.5026 - accuracy: 0.7390 - val_loss: 0.7513 - val_accuracy: 0.5449
# Epoch 34/50
# 191/191 [==============================] - 2s 8ms/step - loss: 0.4947 - accuracy: 0.7504 - val_loss: 0.7525 - val_accuracy: 0.5389
# Epoch 35/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.4955 - accuracy: 0.7424 - val_loss: 0.7824 - val_accuracy: 0.5337
# Epoch 36/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.4801 - accuracy: 0.7533 - val_loss: 0.7685 - val_accuracy: 0.5317
# Epoch 37/50
# 191/191 [==============================] - 2s 11ms/step - loss: 0.4879 - accuracy: 0.7506 - val_loss: 0.7491 - val_accuracy: 0.5386
# Epoch 38/50
# 191/191 [==============================] - 2s 11ms/step - loss: 0.4777 - accuracy: 0.7578 - val_loss: 0.7886 - val_accuracy: 0.5304
# Epoch 39/50
# 191/191 [==============================] - 2s 12ms/step - loss: 0.4723 - accuracy: 0.7628 - val_loss: 0.8021 - val_accuracy: 0.5320
# Epoch 40/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.4674 - accuracy: 0.7636 - val_loss: 0.7834 - val_accuracy: 0.5324
# Epoch 41/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.4675 - accuracy: 0.7637 - val_loss: 0.7898 - val_accuracy: 0.5366
# Epoch 42/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.4544 - accuracy: 0.7751 - val_loss: 0.7914 - val_accuracy: 0.5255
# Epoch 43/50
# 191/191 [==============================] - 2s 8ms/step - loss: 0.4469 - accuracy: 0.7762 - val_loss: 0.7789 - val_accuracy: 0.5274
# Epoch 44/50
# 191/191 [==============================] - 2s 8ms/step - loss: 0.4564 - accuracy: 0.7742 - val_loss: 0.8205 - val_accuracy: 0.5324
# Epoch 45/50
# 191/191 [==============================] - 2s 10ms/step - loss: 0.4507 - accuracy: 0.7783 - val_loss: 0.8205 - val_accuracy: 0.5255
# Epoch 46/50
# 191/191 [==============================] - 2s 10ms/step - loss: 0.4500 - accuracy: 0.7817 - val_loss: 0.7858 - val_accuracy: 0.5265
# Epoch 47/50
# 191/191 [==============================] - 2s 12ms/step - loss: 0.4349 - accuracy: 0.7886 - val_loss: 0.7833 - val_accuracy: 0.5274
# Epoch 48/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.4385 - accuracy: 0.7865 - val_loss: 0.7853 - val_accuracy: 0.5212
# Epoch 49/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.4396 - accuracy: 0.7862 - val_loss: 0.8149 - val_accuracy: 0.5301
# Epoch 50/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.4344 - accuracy: 0.7871 - val_loss: 0.7870 - val_accuracy: 0.5320

# %%
Cnn_acc = model.evaluate(X_test, Y_test, verbose=0)
print("Accuracy: %.2f%%" % (Cnn_acc[1]*100))
# Out:
# Accuracy: 53.20%

# %%
#fcn

# %%
from keras.layers import Dense, Dropout, BatchNormalization
from keras.models import Sequential
from keras.optimizers import Adam

model = Sequential()

# Add a Dense layer with 64 units and 'relu' activation, and input shape of (X_train.shape[1],)
model.add(Dense(units=64, activation='relu', input_shape=(X_train.shape[1],)))
# Add a BatchNormalization layer to normalize the output of the Dense layer
model.add(BatchNormalization())

# Add another Dense layer with 32 units and 'relu' activation
model.add(Dense(units=32, activation='relu'))
# Add another BatchNormalization layer
model.add(BatchNormalization())

# Add a third Dense layer with 16 units and 'relu' activation
model.add(Dense(units=16, activation='relu'))
# Add another BatchNormalization layer
model.add(BatchNormalization())

# Add a Dropout layer with rate of 0.5 to prevent overfitting
model.add(Dropout(0.5))

# Add a Dense layer with 256 units and 'relu' activation
model.add(Dense(units=256, activation='relu'))
# Add another Dropout layer
model.add(Dropout(0.5))
# Add a Dense layer with 1 unit and 'sigmoid' activation for binary classification
model.add(Dense(units=1, activation='sigmoid'))

# Compile the model with binary crossentropy loss and Adam optimizer
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %%
# Fit the model on the training data for 50 epochs
history = model.fit(X_train, Y_train, epochs=50, batch_size=64, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/50
# 191/191 [==============================] - 2s 6ms/step - loss: 0.7234 - accuracy: 0.4954 - val_loss: 0.6913 - val_accuracy: 0.5242
# Epoch 2/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.7041 - accuracy: 0.5160 - val_loss: 0.6875 - val_accuracy: 0.5340
# Epoch 3/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.6931 - accuracy: 0.5332 - val_loss: 0.6824 - val_accuracy: 0.5412
# Epoch 4/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.6784 - accuracy: 0.5705 - val_loss: 0.6837 - val_accuracy: 0.5442
# Epoch 5/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.6671 - accuracy: 0.5941 - val_loss: 0.6874 - val_accuracy: 0.5389
# Epoch 6/50
# 191/191 [==============================] - 1s 6ms/step - loss: 0.6441 - accuracy: 0.6301 - val_loss: 0.7014 - val_accuracy: 0.5429
# Epoch 7/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.6143 - accuracy: 0.6574 - val_loss: 0.7218 - val_accuracy: 0.5403
# Epoch 8/50
# 191/191 [==============================] - 1s 7ms/step - loss: 0.5820 - accuracy: 0.6897 - val_loss: 0.7515 - val_accuracy: 0.5406
# Epoch 9/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.5428 - accuracy: 0.7220 - val_loss: 0.7594 - val_accuracy: 0.5429
# Epoch 10/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.4970 - accuracy: 0.7627 - val_loss: 0.8336 - val_accuracy: 0.5481
# Epoch 11/50
# 191/191 [==============================] - 1s 7ms/step - loss: 0.4500 - accuracy: 0.7877 - val_loss: 0.8973 - val_accuracy: 0.5426
# Epoch 12/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.4000 - accuracy: 0.8205 - val_loss: 0.9432 - val_accuracy: 0.5465
# Epoch 13/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.3543 - accuracy: 0.8493 - val_loss: 1.0476 - val_accuracy: 0.5360
# Epoch 14/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.3242 - accuracy: 0.8642 - val_loss: 1.1416 - val_accuracy: 0.5396
# Epoch 15/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.2938 - accuracy: 0.8796 - val_loss: 1.2236 - val_accuracy: 0.5215
# Epoch 16/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.2520 - accuracy: 0.8997 - val_loss: 1.2824 - val_accuracy: 0.5343
# Epoch 17/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.2431 - accuracy: 0.9046 - val_loss: 1.3488 - val_accuracy: 0.5297
# Epoch 18/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.2135 - accuracy: 0.9173 - val_loss: 1.5492 - val_accuracy: 0.5304
# Epoch 19/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.2050 - accuracy: 0.9202 - val_loss: 1.4687 - val_accuracy: 0.5373
# Epoch 20/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.1842 - accuracy: 0.9306 - val_loss: 1.6625 - val_accuracy: 0.5350
# Epoch 21/50
# 191/191 [==============================] - 2s 8ms/step - loss: 0.1726 - accuracy: 0.9345 - val_loss: 1.6817 - val_accuracy: 0.5320
# Epoch 22/50
# 191/191 [==============================] - 2s 8ms/step - loss: 0.1590 - accuracy: 0.9378 - val_loss: 1.9461 - val_accuracy: 0.5419
# Epoch 23/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.1472 - accuracy: 0.9463 - val_loss: 1.8588 - val_accuracy: 0.5294
# Epoch 24/50
# 191/191 [==============================] - 1s 7ms/step - loss: 0.1460 - accuracy: 0.9492 - val_loss: 1.8079 - val_accuracy: 0.5422
# Epoch 25/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.1367 - accuracy: 0.9491 - val_loss: 1.9722 - val_accuracy: 0.5340
# Epoch 26/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.1385 - accuracy: 0.9485 - val_loss: 1.8791 - val_accuracy: 0.5251
# Epoch 27/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.1394 - accuracy: 0.9484 - val_loss: 1.9715 - val_accuracy: 0.5419
# Epoch 28/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.1136 - accuracy: 0.9610 - val_loss: 2.1650 - val_accuracy: 0.5343
# Epoch 29/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.1119 - accuracy: 0.9592 - val_loss: 2.1625 - val_accuracy: 0.5399
# Epoch 30/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.1143 - accuracy: 0.9582 - val_loss: 2.1653 - val_accuracy: 0.5468
# Epoch 31/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.1075 - accuracy: 0.9627 - val_loss: 2.2269 - val_accuracy: 0.5327
# Epoch 32/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.1017 - accuracy: 0.9630 - val_loss: 2.1251 - val_accuracy: 0.5294
# Epoch 33/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.1075 - accuracy: 0.9610 - val_loss: 2.1975 - val_accuracy: 0.5383
# Epoch 34/50
# 191/191 [==============================] - 2s 8ms/step - loss: 0.1041 - accuracy: 0.9604 - val_loss: 2.3466 - val_accuracy: 0.5271
# Epoch 35/50
# 191/191 [==============================] - 2s 8ms/step - loss: 0.0940 - accuracy: 0.9684 - val_loss: 2.4628 - val_accuracy: 0.5334
# Epoch 36/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.0829 - accuracy: 0.9702 - val_loss: 2.6096 - val_accuracy: 0.5360
# Epoch 37/50
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0913 - accuracy: 0.9681 - val_loss: 2.4703 - val_accuracy: 0.5274
# Epoch 38/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0980 - accuracy: 0.9663 - val_loss: 2.3371 - val_accuracy: 0.5311
# Epoch 39/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0803 - accuracy: 0.9714 - val_loss: 2.4341 - val_accuracy: 0.5327
# Epoch 40/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0789 - accuracy: 0.9729 - val_loss: 2.5632 - val_accuracy: 0.5248
# Epoch 41/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0770 - accuracy: 0.9746 - val_loss: 2.6503 - val_accuracy: 0.5202
# Epoch 42/50
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0926 - accuracy: 0.9684 - val_loss: 2.3321 - val_accuracy: 0.5212
# Epoch 43/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0870 - accuracy: 0.9689 - val_loss: 2.5840 - val_accuracy: 0.5222
# Epoch 44/50
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0746 - accuracy: 0.9744 - val_loss: 2.7746 - val_accuracy: 0.5219
# Epoch 45/50
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0821 - accuracy: 0.9706 - val_loss: 2.5642 - val_accuracy: 0.5219
# Epoch 46/50
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0886 - accuracy: 0.9680 - val_loss: 2.3766 - val_accuracy: 0.5248
# Epoch 47/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.0760 - accuracy: 0.9743 - val_loss: 2.7152 - val_accuracy: 0.5265
# Epoch 48/50
# 191/191 [==============================] - 2s 8ms/step - loss: 0.0864 - accuracy: 0.9689 - val_loss: 2.5495 - val_accuracy: 0.5205
# Epoch 49/50
# 191/191 [==============================] - 2s 9ms/step - loss: 0.0665 - accuracy: 0.9758 - val_loss: 2.8525 - val_accuracy: 0.5225
# Epoch 50/50
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0736 - accuracy: 0.9751 - val_loss: 2.6612 - val_accuracy: 0.5212

# %%
Fcn_acc = model.evaluate(X_test, Y_test, verbose=0)
print("Accuracy: %.2f%%" % (Fcn_acc[1]*100))
# Out:
# Accuracy: 52.12%

# %%
import matplotlib.pyplot as plt

models = ['LSTM', 'Bidirectional LSTM', 'CNN', 'FCN']
accuracy_scores = [Lstm_acc, Blstm_acc, Cnn_acc[1], Fcn_acc[1]]

# Flatten the accuracy_scores list
accuracy_scores = [score[0] if isinstance(score, list) else score for score in accuracy_scores]

plt.bar(models, accuracy_scores)
plt.title('Accuracy scores for different models')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.show()

# %% [markdown]
# <font size="4">From the above graph it can be noted that LSTM has the largest accuracy=0.6148537627341439</font>

# %%
# Statistical Testing

# %%
import numpy as np
from scipy.stats import friedmanchisquare


model_scores = [np.array([Lstm_acc]), np.array([Blstm_acc]), np.array([Cnn_acc[1]]), np.array([Fcn_acc[1]])]

friedman_value, p_value = friedmanchisquare(*model_scores)

print("Friedman test")
print("--------------")
print("Friedman value:", friedman_value)
print("p-value:", p_value)

if p_value < 0.05:
    print("There is a significant difference in the test accuracy scores of the models.")
else:
    print("There is no significant difference in the test accuracy scores of the models.")
# Out:
# Friedman test
# --------------
# Friedman value: 3.0
# p-value: 0.3916251762710877
# There is no significant difference in the test accuracy scores of the models.

# %%
import numpy as np
from scipy.stats import chisquare

model_scores = [Lstm_acc, Blstm_acc, Cnn_acc[1], Fcn_acc[1]]

expected_score = np.mean(model_scores)

# Calculate the chi-squared test statistic and p-value
chi_stat, p_value = chisquare(model_scores, f_exp=expected_score)

print("Chi-squared test results")
print("-------------------------")
print("Chi-squared statistic:", chi_stat)
print("p-value:", p_value)

if p_value < 0.05:
    print("There is a significant difference in the test accuracy scores of the models.")
else:
    print("There is no significant difference in the test accuracy scores of the models.")
# Out:
# Chi-squared test results
# -------------------------
# Chi-squared statistic: 0.015064362351879721
# p-value: 0.9995104657627163
# There is no significant difference in the test accuracy scores of the models.

# %%
import numpy as np
from scipy.stats import ttest_rel

model_scores = [Lstm_acc, Blstm_acc, Cnn_acc[1], Fcn_acc[1]]

# Perform the paired t-test
t_stat, p_value = ttest_rel(model_scores[:-1], model_scores[1:])

print("Paired t-test results")
print("----------------------")
print("t-statistic:", t_stat)
print("p-value:", p_value)

if p_value < 0.05:
    print("There is a significant difference in the test accuracy scores of the models.")
else:
    print("There is no significant difference in the test accuracy scores of the models.")
# Out:
# Paired t-test results
# ----------------------
# t-statistic: 0.6637948170525152
# p-value: 0.5751032027577005
# There is no significant difference in the test accuracy scores of the models.
